# %%
#!pip install climetlab
#!pip install my-project-my-dataset

# %%
import climetlab as cml

# %%
cmlds = cml.load_source(
    "intake",
    catalog="https://raw.githubusercontent.com/intake/intake-xarray/master/examples/catalog.yml",
    item="image",
)

# %%
ds = cmlds.to_xarray()
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (y: 256, x: 256, channel: 3)
# Coordinates:
#   * y        (y) int64 0 1 2 3 4 5 6 7 8 ... 247 248 249 250 251 252 253 254 255
#   * x        (x) int64 0 1 2 3 4 5 6 7 8 ... 247 248 249 250 251 252 253 254 255
#   * channel  (channel) int64 0 1 2
# Data variables:
#     image    (y, x, channel) uint8 212 214 213 214 215 216 ... 95 97 82 97 98 84

# %% [markdown]
# ## Openning directly with intake is also possible:

# %%
import intake

xcat = intake.open_catalog(
    "https://raw.githubusercontent.com/intake/intake-xarray/master/examples/catalog.yml"
)
display(list(xcat))
# Out:
# ['esgf',
#  'geotiff',
#  'image',
#  'images_labelled',
#  'images_unlabelled',
#  'grib_thredds']

# %%
item = xcat.grib_thredds
# item.plot.band_image()
# da = item.read()  # fail : error 400

# %%
item = xcat.geotiff
# item.plot.band_image()
# da = item.read()  # fail : Need libLerc.so

# %%
item = xcat.esgf
# item.plot.band_image()
# da = item.read()  # Need pydap. Then error 404.

# %%
item = xcat.image
# item.plot.band_image()
da = item.read()  # Need skimage (provided by scikit-image)

# %%
da
# Out:
# <xarray.DataArray (y: 256, x: 256, channel: 3)>
# array([[[212, 214, 213],
#         [214, 215, 216],
#         [211, 212, 213],
#         ...,
#         [179, 171, 156],
#         [180, 172, 157],
#         [178, 170, 155]],
#
#        [[211, 212, 213],
#         [214, 215, 216],
#         [208, 208, 210],
#         ...,
#         [176, 167, 152],
#         [178, 170, 155],
#         [178, 170, 155]],
#
#        [[217, 216, 219],
#         [208, 208, 210],
#         [210, 211, 212],
#         ...,
# ...
#         ...,
#         [ 95,  97,  82],
#         [ 98, 100,  86],
#         [ 98, 100,  86]],
#
#        [[115, 109, 104],
#         [115, 109, 107],
#         [109, 102, 100],
#         ...,
#         [ 93,  95,  80],
#         [ 97,  98,  84],
#         [ 97,  98,  84]],
#
#        [[114, 107, 105],
#         [114, 107, 105],
#         [112, 105, 104],
#         ...,
#         [ 95,  97,  82],
#         [ 95,  97,  82],
#         [ 97,  98,  84]]], dtype=uint8)
# Coordinates:
# ...
